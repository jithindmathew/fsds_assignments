# %% [markdown]
# ```
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
#
# *, 'hello', -87.8, -, /, +, 6
# ```
# ### Ans.
#
# Values :
# - 'hello'
# - -87.8
# - 6
#
# Expressions :
# - ```*```
# - ```-```
# - ```/```
# - ```+```
#
# ---

# %% [markdown]
# ```
# 2. What is the difference between string and variable?
# ```
#
# ### Ans.
#
# A variable is used to store information in python whereas string is a type of information stored using a variable
#
# ---

# %% [markdown]
# ```
# 3. Describe three different data types.
# ```
# ### Ans.
#
# 1) ```int``` : This is a data type used to store number in the form of integer values in python
#
# 2) ```float``` : This is a data type used to store number in the form of numbers with decimal points in python
#
# 3) ```bool``` : This is a data type used to store logical values, i.e. ```True``` or ```False```
#
# ---

# %% [markdown]
# ```
# 4. What is an expression made up of? What do all expressions do?
# ```
# ### Ans.
#
# An expression is made up of a combination of values, variables and operators.
#
# Expressions are used to create other useful value.
#
# ---

# %% [markdown]
# ```
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?
# ```
# ### Ans.
#
# In general expressions produce some results and statements are used to do something, generally with the result values generated by expressions.
#
# ---

# %% [markdown]
# ```
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
# ```
#
# ### Ans.
#
# Here, we are adding `1` to `bacon` with a value of `22`. But we did not assign the new value to the variable `bacon` i.e.
#
# We did not do this
#
# ```
# bacon = bacon + 1
# ```
#
# Therefore the variable bacon still contains the value `22`
#
# ---

# %% [markdown]
# ```
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
# ```
#
# ### Ans.
#
# The value in both cases will be `'spamspamspam'`
#
# ---

# %% [markdown]
# ```
# 8. Why is eggs a valid variable name while 100 is invalid?
# ```
#
# Ans.
#
# Because variable names must start with a letter or underscore character and `100` starts with a number `1`
#
# ---

# %% [markdown]
# ```
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
# ```
#
# Ans.
#
# 1) To get integer version of a value, use `int(value)`
# 1) To get floating-point version of a value, use `float(value)`
# 1) To get string version of a value, use `str(value)`
#
# ---

# %% [markdown]
# ```
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
# ```
#
# ### Ans.
#
# Because we are trying to join 2 strings and an integer together.
#
# To solve this, we have to convert `99` into a string first.
#
# ```
# 'I have eaten ' + str(99) + ' burritos.'
# ```
#
# ---
